# %%
import pandas as pd

clmy_msg = pd.read_csv('C:\\Users\\astnv\\Desktop\\Python\\Anaconda\\Project\\CLMY_MSG_KR.csv', encoding = 'cp949')

clmy_name = clmy_msg['재난유형명'].unique() # 재난유형명의 종류를 모아둔 리스트

clmy_name_value = list(clmy_msg['재난유형명'].values) # '재난유형명' 항목의 모든 값을 모아둔 리스트
clmy_date_value = list(clmy_msg['수신일시'].values) # '수신일시' 항목의 모든 값을 모아둔 리스트

DataCollect2 = {}

def getYear(year):
    length = len(year)
    result = year[length - 4] + year[length - 3] + year[length - 2] + year[length - 1]
    return result


k = 0
for i in clmy_date_value:
    clmy_date_value[k] = getYear(i)
    k += 1
    
DataCollect2['재난유형명'] = clmy_name_value
DataCollect2['수신년도'] = clmy_date_value

frame2 = pd.DataFrame(DataCollect2)
frame2 = frame2[['재난유형명','수신년도']]
frame2
# Out:
#       재난유형명  수신년도
# 0        호우  2018
# 1        기타  2018
# 2        기타  2018
# 3        태풍  2018
# 4        태풍  2018
# 5        태풍  2018
# 6     풍랑,강풍  2018
# 7      폭풍해일  2018
# 8        호우  2018
# 9        호우  2018
# 10       호우  2018
# 11       호우  2018
# 12       호우  2018
# 13       호우  2018
# 14       호우  2018
# 15       호우  2018
# 16       호우  2018
# 17       호우  2018
# 18       호우  2018
# 19       호우  2018
# 20       호우  2018
# 21       호우  2018
# 22       호우  2018
# 23       호우  2018
# 24       호우  2018
# 25       호우  2018
# 26       호우  2018
# 27       호우  2018
# 28       호우  2018
# 29       호우  2018
# ...     ...   ...
# 5799     강풍  2016
# 5800     안개  2016
# 5801     안개  2016
# 5802  풍랑,강풍  2016
# 5803     호우  2016
# 5804  풍랑,강풍  2016
# 5805  풍랑,강풍  2016
# 5806     기타  2016
# 5807     호우  2016
# 5808  풍랑,강풍  2016
# 5809     호우  2016
# 5810     호우  2016
# 5811     안개  2016
# 5812     호우  2016
# 5813  풍랑,강풍  2016
# 5814     호우  2016
# 5815     기타  2016
# 5816  풍랑,강풍  2016
# 5817  풍랑,강풍  2016
# 5818  풍랑,강풍  2016
# 5819     강풍  2016
# 5820     호우  2016
# 5821     호우  2016
# 5822     호우  2016
# 5823     호우  2016
# 5824     호우  2016
# 5825     호우  2016
# 5826     호우  2016
# 5827     호우  2016
# 5828     호우  2016
#
# [5829 rows x 2 columns]
